# %%
import mercury as mr

# %% [markdown]
# ## Starter Web App
#
# Provide name and age and display them.

# %%
name = mr.TextInput(label='What is your name?', value='Piotr')
age = mr.Slider(label='How old are you?', min=18, max=100, value=40)

# %%
mr.Markdown(f'# Hi {name.value}!')
print('You are', age.value)
